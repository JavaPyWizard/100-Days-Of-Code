# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Create a side-by-side bar chart comparing runs of Sachin, Kohli, and Sehwag over 5 selected years.

# %%
years = [2003, 2007, 2011, 2015, 2019]
sachin = [1200, 1000, 1100, 0, 0]
kohli = [0, 600, 1300, 1350, 1500]
sehwag = [1100, 950, 700, 0, 0]

x=np.arange(len(years))
plt.bar(x-0.25, sachin, width=0.25, label="Sachin")
plt.bar(x, kohli, width=0.25, label="Kohli")
plt.bar(x+0.25, sehwag, width=0.25, label="Sehwag")
plt.xticks(x,years)
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.grid(True)
plt.legend()

plt.tight_layout()

# %% [markdown]
# ---
# ## Create a horizontal bar chart showing total runs scored in their debut 5 years.

# %%
years = [1, 2, 3, 4, 5]

sachin = [200, 350, 580, 900, 1080]
sehwag = [215, 450, 650, 920, 1100]
kohli = [325, 1025, 1380, 1590, 1720]

plt.plot(years, sachin, label="Sachin", marker='o')
plt.plot(years, sehwag, label="Sehwag", marker='^')
plt.plot(years, kohli, label="Kohli", marker='s')

plt.xlabel("Years Since Debut")
plt.ylabel("Runs Scored")
plt.title("First 5 Years Performance After Debut")
plt.xticks(years, ["Year 1", "Year 2", "Year 3", "Year 4", "Year 5"])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = [1, 2, 3, 4, 5]
sachin = [200, 350, 580, 900, 1080]
sehwag = [215, 450, 650, 920, 1100]
kohli = [325, 1025, 1380, 1590, 1720]

y = np.array(years)
height = 0.25

plt.barh(y - height, sachin, height=height, label="Sachin")
plt.barh(y, sehwag, height=height, label="Sehwag")
plt.barh(y + height, kohli, height=height, label="Kohli")

plt.ylabel("Years Since Debut")
plt.xlabel("Runs Scored")
plt.title("First 5 Years Performance After Debut")
plt.yticks(years, ["Year 1", "Year 2", "Year 3", "Year 4", "Year 5"])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
